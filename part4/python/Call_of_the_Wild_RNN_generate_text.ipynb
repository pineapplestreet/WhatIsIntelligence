# %%
# load all libraries and shared functions
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from shared_lstm_functions import *
jojo_test()
# Out:
# All of our functions are here in memory....

# %%
# load a given model
model_name = 'cotw_rnn_v25.net'
with open('models/'+model_name, 'rb') as f:
    checkpoint = torch.load(f)
    
loaded = CharRNN(checkpoint['tokens'], n_hidden=checkpoint['n_hidden'], n_layers=checkpoint['n_layers'])
loaded.load_state_dict(checkpoint['state_dict'])
# Out:
# <All keys matched successfully>

# %%
# generate 10,000 characters of new text
output1 = sample(loaded, 500, cuda=False, top_k=5, prime="Buck did not read the ")
output2 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nBuck lived at a big house in ")
output3 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nAnd over this great demesne Buck ")
output4 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nBut Buck was neither house-dog nor ")
output5 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nHis father, Elmo, a huge ")
output6 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nAnd this was the manner of ")
output7 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nThe Judge was at a ")
output8 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nBuck had accepted the ")
output9 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nThe next he knew, he was ")
output10 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nHis hand was wrapped in ")
output11 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nThe kidnapper undid the ")
output12 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nDazed, suffering intolerable pain from ")
output13 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nThere he lay for the ")
output14 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nBut the saloon-keeper let him ")
output15 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nFor two days and nights this  ")
output16 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nHe was glad for one thing: ")
output17 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nFour men gingerly carried the ")
output18 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nThere was an instantaneous scattering of ")
output19 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nBuck rushed at the ")
output20 = sample(loaded, 500, cuda=False, top_k=5, prime="\n\nAnd Buck was truly a ")
output = output1+output2+output3+output4+output5+output6+output7+output8+output9+output10+output11+output12+output13+output14+output15+output16+output17+output18+output19+output20
print(output)
# Out:
# Buck did not read the werith of as the wong,
# his sourling he drawn to was
# herth herd soul and hald he was he dod, were heant of a thand to that so that the stirg this welch
# ald at was an he finte of streng, whine the with of than to the forg and went him the fean whith and he did had they streacing to the sont
# of the fith and stalr. To the fore to she while, the fast was, and to the tele to wonger. And were the were to whacing the would.
#
# Buck sand. Betanded and he sored and as of a them. The selir a man to them as an
#
# Buck lived at a big house in the stranged and harfed his thang a thould the forle had so that the sofled, and the dang. Alould was the trice, with has was
# to when his stanthing to the frore of the trear the were his along of
# a cound the sould he was as the terlang offy and trased and a their to mes and the strengen, and he wime was with him and and starneds here
# and tith of a frest of the somless and the sereres, he down
# ...

# %%
# save our output to a txt file
file1 = open('output/'+model_name+".txt","w")
file1.write(output)
file1.close()
print(output)
# Out:
# Buck did not read the werith of as the wong,
# his sourling he drawn to was
# herth herd soul and hald he was he dod, were heant of a thand to that so that the stirg this welch
# ald at was an he finte of streng, whine the with of than to the forg and went him the fean whith and he did had they streacing to the sont
# of the fith and stalr. To the fore to she while, the fast was, and to the tele to wonger. And were the were to whacing the would.
#
# Buck sand. Betanded and he sored and as of a them. The selir a man to them as an
#
# Buck lived at a big house in the stranged and harfed his thang a thould the forle had so that the sofled, and the dang. Alould was the trice, with has was
# to when his stanthing to the frore of the trear the were his along of
# a cound the sould he was as the terlang offy and trased and a their to mes and the strengen, and he wime was with him and and starneds here
# and tith of a frest of the somless and the sereres, he down
# ...

# %%
sum(p.numel() for p in loaded.parameters())

# %%
loaded
